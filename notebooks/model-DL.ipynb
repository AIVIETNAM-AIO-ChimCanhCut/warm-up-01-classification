# %% [markdown]
# ## Data Preprocessing — Customer Churn Classification
#
# Pipeline: Drop ID → Handle Missing → Encode Categoricals → Feature Engineering → Split → Scale

# %% [markdown]
# ### Imports & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, StandardScaler

train = pd.read_csv("/content/data/churn_train.csv")
test = pd.read_csv("/content/data/churn_test.csv")

train_df = pd.concat([train, test], axis = 0)
print(f"Train shape: {train_df.shape}")
# Out:
# Train shape: (505207, 12)

# %% [markdown]
# ### 1. Drop cột không cần thiết
#
# - `CustomerID` là cột định danh, không mang thông tin dự đoán
# - Nếu giữ lại, model sẽ "memorize" ID → overfitting

# %%
drop_cols = ["CustomerID"]

train_df = train_df.drop(columns=drop_cols)

print(f"Train columns: {train_df.columns.tolist()}")
print(f"Train shape sau khi drop: {train_df.shape}")
# Out:
# Train columns: ['Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'Churn']
# Train shape sau khi drop: (505207, 11)

# %% [markdown]
# ### 2. Xử lý Missing Values
#
# - Train có đúng **1 dòng** (index 199295) tất cả cột đều null
# - Test **không có** missing values

# %%
# Kiểm tra missing trước khi xử lý
print(f"Train missing rows: {train_df.isnull().any(axis=1).sum()}")

# Drop dòng missing
train_df = train_df.dropna()

# Reset index
train_df = train_df.reset_index(drop=True)

print("--- Sau Khi Xử Lý ---")
print(f"Train shape: {train_df.shape}")
print(f"Train missing: {train_df.isnull().sum().sum()}")
# Out:
# Train missing rows: 1
# --- Sau Khi Xử Lý ---
# Train shape: (505206, 11)
# Train missing: 0

# %% [markdown]
# ### 3. Encode Categorical Features
#
# | Cột | Giá trị | Phương pháp | Lý do |
# |-----|---------|-------------|-------|
# | `Gender` | Female, Male | LabelEncoder | Binary → 0/1 |
# | `Subscription Type` | Basic, Standard, Premium | OrdinalEncoder | Có thứ bậc tự nhiên |
# | `Contract Length` | Monthly, Quarterly, Annual | OrdinalEncoder | Có thứ bậc tự nhiên |

# %%
# Kiểm tra các giá trị unique trước khi encode
print("Gender:", train_df["Gender"].unique())
print("Subscription Type:", train_df["Subscription Type"].unique())
print("Contract Length:", train_df["Contract Length"].unique())
# Out:
# Gender: ['Female' 'Male']
# Subscription Type: ['Standard' 'Basic' 'Premium']
# Contract Length: ['Annual' 'Monthly' 'Quarterly']

# %%
# --- Gender: Binary → LabelEncoder ---
le_gender = LabelEncoder()
train_df["Gender"] = le_gender.fit_transform(train_df["Gender"])

print(f"Gender mapping: {dict(zip(le_gender.classes_, le_gender.transform(le_gender.classes_)))}")
# Out:
# Gender mapping: {'Female': np.int64(0), 'Male': np.int64(1)}

# %%
# --- Subscription Type: Ordinal (Basic = 0 < Standard = 1 < Premium = 2) ---
sub_categories = [["Basic", "Standard", "Premium"]]
oe_sub = OrdinalEncoder(categories=sub_categories)

train_df["Subscription Type"] = oe_sub.fit_transform(train_df[["Subscription Type"]])

print(f"Subscription Type mapping: Basic=0, Standard=1, Premium=2")
print(f"Unique values: {sorted(train_df['Subscription Type'].unique())}")
# Out:
# Subscription Type mapping: Basic=0, Standard=1, Premium=2
# Unique values: [np.float64(0.0), np.float64(1.0), np.float64(2.0)]

# %%
# --- Contract Length: Ordinal (Monthly=0 < Quarterly=1 < Annual=2) ---
contract_categories = [["Monthly", "Quarterly", "Annual"]]
oe_contract = OrdinalEncoder(categories=contract_categories)

train_df["Contract Length"] = oe_contract.fit_transform(train_df[["Contract Length"]])

print(f"Contract Length mapping: Monthly=0, Quarterly=1, Annual=2")
print(f"Unique values: {sorted(train_df['Contract Length'].unique())}")
# Out:
# Contract Length mapping: Monthly=0, Quarterly=1, Annual=2
# Unique values: [np.float64(0.0), np.float64(1.0), np.float64(2.0)]

# %%
# Kiểm tra toàn bộ dtypes sau khi encode
print("=== Data types sau encoding ===")
print(train_df.dtypes)
print(f"\nTrain shape: {train_df.shape}")
train_df.head()
# Out:
# === Data types sau encoding ===
# Age                  float64
# Gender                 int64
# Tenure               float64
# Usage Frequency      float64
# Support Calls        float64
# Payment Delay        float64
# Subscription Type    float64
# Contract Length      float64
# Total Spend          float64
# Last Interaction     float64
# Churn                float64
# dtype: object
#
# Train shape: (505206, 11)
#     Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0  30.0       0    39.0             14.0            5.0           18.0
# 1  65.0       0    49.0              1.0           10.0            8.0
# 2  55.0       0    14.0              4.0            6.0           18.0
# 3  58.0       1    38.0             21.0            7.0            7.0
# 4  23.0       1    32.0             20.0            5.0            8.0
#
#    Subscription Type  Contract Length  Total Spend  Last Interaction  Churn
# 0                1.0              2.0        932.0              17.0    1.0
# 1                0.0              0.0        557.0               6.0    1.0
# 2                0.0              1.0        185.0               3.0    1.0
# 3                1.0              0.0        396.0              29.0    1.0
# 4                0.0              0.0        617.0              20.0    1.0

# %% [markdown]
# ### 4. Feature Engineering
#
# Tạo các feature mới dựa trên domain knowledge:
#
# | Feature | Công thức | Ý nghĩa |
# |---------|----------|----------|
# | `Spend_per_Tenure` | Total Spend / Tenure | Chi tiêu TB mỗi tháng |
# | `Usage_per_Tenure` | Usage Frequency / Tenure | Mức sử dụng theo thời gian |
# | `Support_per_Tenure` | Support Calls / Tenure | Tần suất gọi support |
# | `Delay_x_Support` | Payment Delay × Support Calls | Risk interaction feature |

# %%
def add_features(df):
    """Tạo các features mới cho DataFrame."""
    df = df.copy()

    # Chi tiêu trung bình mỗi nhiệm kỳ
    df["Spend_per_Tenure"] = df["Total Spend"] / df["Tenure"]

    # Mức sử dụng dịch vụ theo thời gian
    df["Usage_per_Tenure"] = df["Usage Frequency"] / df["Tenure"]

    # Tần suất liên hệ hỗ trợ theo thời gian
    df["Support_per_Tenure"] = df["Support Calls"] / df["Tenure"]

    # Interaction: khách hàng vừa trễ hạn vừa gọi support nhiều => risk cao
    df["Delay_x_Support"] = df["Payment Delay"] * df["Support Calls"]

    return df

train_df = add_features(train_df)

print(f"Train shape sau feature engineering: {train_df.shape}")
print(f"\nCác cột mới: {train_df.columns.tolist()[-4:]}")
train_df.head()
# Out:
# Train shape sau feature engineering: (505206, 15)
#
# Các cột mới: ['Spend_per_Tenure', 'Usage_per_Tenure', 'Support_per_Tenure', 'Delay_x_Support']
#     Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0  30.0       0    39.0             14.0            5.0           18.0
# 1  65.0       0    49.0              1.0           10.0            8.0
# 2  55.0       0    14.0              4.0            6.0           18.0
# 3  58.0       1    38.0             21.0            7.0            7.0
# 4  23.0       1    32.0             20.0            5.0            8.0
#
#    Subscription Type  Contract Length  Total Spend  Last Interaction  Churn  \
# 0                1.0              2.0        932.0              17.0    1.0
# 1                0.0              0.0        557.0               6.0    1.0
# 2                0.0              1.0        185.0               3.0    1.0
# 3                1.0              0.0        396.0              29.0    1.0
# 4                0.0              0.0        617.0              20.0    1.0
#
#    Spend_per_Tenure  Usage_per_Tenure  Support_per_Tenure  Delay_x_Support
# 0         23.897436          0.358974            0.128205             90.0
# 1         11.367347          0.020408            0.204082             80.0
# 2         13.214286          0.285714            0.428571            108.0
# 3         10.421053          0.552632            0.184211             49.0
# 4         19.281250          0.625000            0.156250             40.0

# %%
# Kiểm tra có inf hay NaN sau feature engineering không
print("--- Kiểm tra giá trị bất thường ---")
print(f"Inf values in train: {np.isinf(train_df.select_dtypes(include=[np.number])).sum().sum()}")
print(f"NaN values in train: {train_df.isnull().sum().sum()}")
# Out:
# --- Kiểm tra giá trị bất thường ---
# Inf values in train: 0
# NaN values in train: 0

# %% [markdown]
# ### 5. Tách dữ liệu: Train / Validation / Test
#
# - **Train** (80%): huấn luyện model
# - **Validation** (20%): đánh giá & tune hyperparameters
# - **Test**: đánh giá cuối cùng (chỉ dùng 1 lần)
# - Dùng `stratify` để giữ tỷ lệ class balance

# %%
# Tách features và target
TARGET = "Churn"

X_train_full = train_df.drop(columns=[TARGET])
y_train_full = train_df[TARGET]

# Lưu tên features để dùng cho feature importance
feature_names = X_train_full.columns.tolist()
print(f"Feature names ({len(feature_names)}): {feature_names}")
# Out:
# Feature names (14): ['Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'Spend_per_Tenure', 'Usage_per_Tenure', 'Support_per_Tenure', 'Delay_x_Support']

# %%
# Split: 80% train, 20% validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    random_state=42,
    # giữ tỉ lệ Churn/Not Churn
    stratify=y_train_full
)

print(f"X_train: {X_train.shape} | y_train Churn ratio: {y_train.mean():.4f}")
print(f"X_val:  {X_val.shape}  | y_val Churn ratio:  {y_val.mean():.4f}")
# Out:
# X_train: (404164, 14) | y_train Churn ratio: 0.5552
# X_val:  (101042, 14)  | y_val Churn ratio:  0.5552

# %% [markdown]
# ### 6. Feature Scaling
#
# - Dùng `StandardScaler`: chuẩn hóa về mean=0, std=1

# %%
scaler = StandardScaler()

# chỉ fit trên tập train để tránh data leakage
X_train_scaled = scaler.fit_transform(X_train)

X_val_scaled = scaler.transform(X_val)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=feature_names)
X_val_scaled = pd.DataFrame(X_val_scaled, columns=feature_names)

y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)

print("=== Thống kê X_train sau scaling ===")
print(X_train_scaled.describe().round(4))
# Out:
# === Thống kê X_train sau scaling ===
#                Age       Gender       Tenure  Usage Frequency  Support Calls  \
# count  404164.0000  404164.0000  404164.0000      404164.0000    404164.0000
# mean        0.0000       0.0000       0.0000          -0.0000         0.0000
# std         1.0000       1.0000       1.0000           1.0000         1.0000
# min        -1.7126      -1.1167      -1.7616          -1.7085        -1.2225
# 25%        -0.8445      -1.1167      -0.8914          -0.8965        -0.9034
# 50%         0.0235       0.8955       0.0369           0.0314        -0.2652
# 75%         0.7338       0.8955       0.8491           0.8433         0.6921
# max         1.9964       0.8955       1.6613           1.6552         1.9685
#
#        Payment Delay  Subscription Type  Contract Length  Total Spend  \
# count    404164.0000        404164.0000      404164.0000  404164.0000
# mean          0.0000            -0.0000           0.0000      -0.0000
# std           1.0000             1.0000           1.0000       1.0000
# min          -1.5974            -1.2415          -1.5488      -2.1200
# 25%          -0.8874            -1.2415          -0.2329      -0.7094
# 50%          -0.0591            -0.0129          -0.2329       0.1180
# 75%           0.7693             1.2156           1.0830       0.8315
# max           1.9526             1.2156           1.0830       1.5492
#
#        Last Interaction  Spend_per_Tenure  Usage_per_Tenure  \
# count       404164.0000       404164.0000       404164.0000
# mean             0.0000            0.0000            0.0000
# std              1.0000            1.0000            1.0000
# min             -1.5814           -0.4717           -0.4543
# 25%             -0.8843           -0.3519           -0.3555
# 50%             -0.0710           -0.2764           -0.2588
# 75%              0.8585           -0.0856           -0.0566
# max              1.7881           10.4003           11.6721
#
#        Support_per_Tenure  Delay_x_Support
# count         404164.0000      404164.0000
# mean              -0.0000          -0.0000
# std                1.0000           1.0000
# min               -0.3866          -0.8463
# 25%               -0.3375          -0.7412
# 50%               -0.2398          -0.4111
# 75%               -0.0625           0.4144
# max               13.1184           3.6561

# %% [markdown]
# ### 8. Tổng Kết

# %%
print("=" * 60)
print("PREPROCESSING SUMMARY")
print("=" * 60)
print(f"\n Dataset sizes:")
print(f"   Train:      {X_train_scaled.shape}")
print(f"   Validation:       {X_val_scaled.shape}")
print(f"\n Features ({len(feature_names)}):")
for i, feat in enumerate(feature_names, 1):
    print(f"   {i:2d}. {feat}")
print(f"\n Target: Churn (binary)")
print(f"   Train Churn ratio:  {y_train.mean():.4f}")
print(f"   Validation Churn ratio:   {y_val.mean():.4f}")
print(f"\n Missing values: 0")
# Out:
# ============================================================
# PREPROCESSING SUMMARY
# ============================================================
#
#  Dataset sizes:
#    Train:      (404164, 14)
#    Validation:       (101042, 14)
#
#  Features (14):
#     1. Age
#     2. Gender
#     3. Tenure
#     4. Usage Frequency
#     5. Support Calls
#     6. Payment Delay
#     7. Subscription Type
#     8. Contract Length
#     9. Total Spend
#    10. Last Interaction
#    11. Spend_per_Tenure
#    12. Usage_per_Tenure
#    13. Support_per_Tenure
#    14. Delay_x_Support
#
#  Target: Churn (binary)
#    Train Churn ratio:  0.5552
#    Validation Churn ratio:   0.5552
#
#  Missing values: 0

# %% [markdown]
# ---
#
# ### Ghi chú cho bước tiếp theo (Model Training)
#
# Các biến sẵn sàng để sử dụng:
# - `X_train_scaled`, `y_train` → Huấn luyện model
# - `X_val_scaled`, `y_val` → Đánh giá
# - `feature_names` → Tên các features (cho feature importance)
# - `scaler` → Scaler object (cần save để dùng cho inference)

# %% [markdown]
# ## Modeling — Using Deep learning

# %% [markdown]
# ### Import libraries

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

# %% [markdown]
# ### Define Hyperparameters

# %%
EPOCHS = 100
BATCH_SIZE = 512
LR = 0.0001

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device}")
# Out:
# Using cuda

# %% [markdown]
# ### Define dataset

# %%
class ChurnDataset(Dataset):
    def __init__(self, X, y) -> None:
        super().__init__()
        X, y = X.to_numpy(), y.to_numpy()
        self.X = torch.tensor(X, dtype=torch.float).to(device)
        self.y = torch.tensor(y, dtype=torch.float).to(device)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
train_churn_dataset = ChurnDataset(X_train_scaled, y_train)
val_churn_dataset = ChurnDataset(X_val_scaled, y_val)

train_loader = DataLoader(train_churn_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_churn_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### Define models
#
# Baseline: Input(14) -> Hidden(64) -> Hidden(32) -> Output(1)

# %%
class BaseNeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, output_dim),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.fc(input)

# %% [markdown]
# #Train models

# %%
base_nn = BaseNeuralNetwork(14, 1).to(device)
loss_fn = nn.BCELoss()
optimizer = torch.optim.Adam(base_nn.parameters(), lr=LR)

# %%
def train_and_val_loop(train_loader, val_loader, model, loss_fn, optimizer):
    train_losses, val_losses = [], []

    for i in range(EPOCHS):
        model.train()
        running_loss = 0.0

        print(f"------------------EPOCH {i+1}:------------------")
        for batch, (X, y) in enumerate(train_loader):
            y_pred = model(X)
            y_pred = y_pred.squeeze()
            loss = loss_fn(y_pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        print(f"Loss: {avg_loss:>7f}")
        train_losses.append(avg_loss)

        val_loss = val_loop(val_loader, model, loss_fn)
        val_losses.append(val_loss)

    return train_losses, val_losses

def val_loop(data_loader, model, loss_fn):
    num_batches = len(data_loader)
    size = len(data_loader.dataset)
    total_loss, correct = 0, 0

    model.eval()
    with torch.no_grad():
      for X, y in data_loader:
          y_pred = model(X)
          y_pred = y_pred.squeeze()
          loss = loss_fn(y_pred, y)

          total_loss += loss.item()
          predictions = (y_pred >= 0.5).float()
          correct += (predictions == y).float().sum().item()

    total_loss /= num_batches
    correct /= size
    print(f"Validation : \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {total_loss:>8f} \n")
    return total_loss

# %%
train_losses, val_losses = train_and_val_loop(train_loader, val_loader, base_nn, loss_fn, optimizer)
# Out:
# ------------------EPOCH 1:------------------
# Loss: 0.487795
# Validation :
#  Accuracy: 84.5%, Avg loss: 0.378546
#
# ------------------EPOCH 2:------------------
# Loss: 0.359273
# Validation :
#  Accuracy: 86.7%, Avg loss: 0.339459
#
# ------------------EPOCH 3:------------------
# Loss: 0.323705
# Validation :
#  Accuracy: 88.8%, Avg loss: 0.306973
#
# ------------------EPOCH 4:------------------
# Loss: 0.297793
# Validation :
#  Accuracy: 89.8%, Avg loss: 0.287035
#
# ------------------EPOCH 5:------------------
# Loss: 0.283072
# Validation :
#  Accuracy: 90.3%, Avg loss: 0.275934
#
# ------------------EPOCH 6:------------------
# Loss: 0.274332
# Validation :
#  Accuracy: 90.7%, Avg loss: 0.268830
#
# ------------------EPOCH 7:------------------
# Loss: 0.268331
# Validation :
#  Accuracy: 90.9%, Avg loss: 0.263590
#
# ------------------EPOCH 8:------------------
# Loss: 0.263909
# Validation :
#  Accuracy: 90.9%, Avg loss: 0.259550
#
# ------------------EPOCH 9:------------------
# Loss: 0.260313
# Validation :
#  Accuracy: 91.1%, Avg loss: 0.256208
#
# ------------------EPOCH 10:------------------
# Loss: 0.257460
# Validation :
#  Accuracy: 91.2%, Avg loss: 0.253652
#
# ------------------EPOCH 11:------------------
# Loss: 0.254821
# Validation :
#  Accuracy: 91.3%, Avg loss: 0.251035
#
# ------------------EPOCH 12:------------------
# Loss: 0.252542
# Validation :
#  Accuracy: 91.4%, Avg loss: 0.248877
#
# ------------------EPOCH 13:------------------
# Loss: 0.250242
# Validation :
#  Accuracy: 91.5%, Avg loss: 0.246798
#
# ------------------EPOCH 14:------------------
# Loss: 0.248074
# Validation :
#  Accuracy: 91.6%, Avg loss: 0.244634
#
# ------------------EPOCH 15:------------------
# Loss: 0.245890
# Validation :
#  Accuracy: 91.7%, Avg loss: 0.242633
#
# ------------------EPOCH 16:------------------
# Loss: 0.243864
# Validation :
#  Accuracy: 91.8%, Avg loss: 0.240691
#
# ------------------EPOCH 17:------------------
# Loss: 0.241783
# Validation :
#  Accuracy: 91.9%, Avg loss: 0.238723
#
# ------------------EPOCH 18:------------------
# Loss: 0.239878
# Validation :
#  Accuracy: 91.9%, Avg loss: 0.236894
#
# ------------------EPOCH 19:------------------
# Loss: 0.237969
# Validation :
#  Accuracy: 92.0%, Avg loss: 0.235143
#
# ------------------EPOCH 20:------------------
# Loss: 0.236083
# Validation :
#  Accuracy: 92.0%, Avg loss: 0.233544
#
# ------------------EPOCH 21:------------------
# Loss: 0.234443
# Validation :
#  Accuracy: 92.1%, Avg loss: 0.231801
#
# ------------------EPOCH 22:------------------
# Loss: 0.232783
# Validation :
#  Accuracy: 92.2%, Avg loss: 0.230236
#
# ------------------EPOCH 23:------------------
# Loss: 0.231192
# Validation :
#  Accuracy: 92.3%, Avg loss: 0.228916
#
# ------------------EPOCH 24:------------------
# Loss: 0.229745
# Validation :
#  Accuracy: 92.3%, Avg loss: 0.227636
#
# ------------------EPOCH 25:------------------
# Loss: 0.228388
# Validation :
#  Accuracy: 92.3%, Avg loss: 0.226314
#
# ------------------EPOCH 26:------------------
# Loss: 0.227138
# Validation :
#  Accuracy: 92.4%, Avg loss: 0.225320
#
# ------------------EPOCH 27:------------------
# Loss: 0.225941
# Validation :
#  Accuracy: 92.5%, Avg loss: 0.223999
#
# ------------------EPOCH 28:------------------
# Loss: 0.224808
# Validation :
#  Accuracy: 92.5%, Avg loss: 0.223108
#
# ------------------EPOCH 29:------------------
# Loss: 0.223763
# Validation :
#  Accuracy: 92.6%, Avg loss: 0.221970
#
# ------------------EPOCH 30:------------------
# Loss: 0.222802
# Validation :
#  Accuracy: 92.6%, Avg loss: 0.221014
#
# ------------------EPOCH 31:------------------
# Loss: 0.221819
# Validation :
#  Accuracy: 92.6%, Avg loss: 0.220113
#
# ------------------EPOCH 32:------------------
# Loss: 0.220871
# Validation :
#  Accuracy: 92.6%, Avg loss: 0.219234
#
# ------------------EPOCH 33:------------------
# Loss: 0.219981
# Validation :
#  Accuracy: 92.7%, Avg loss: 0.218331
#
# ------------------EPOCH 34:------------------
# Loss: 0.219144
# Validation :
#  Accuracy: 92.7%, Avg loss: 0.217667
#
# ------------------EPOCH 35:------------------
# Loss: 0.218382
# Validation :
#  Accuracy: 92.7%, Avg loss: 0.216851
#
# ------------------EPOCH 36:------------------
# Loss: 0.217550
# Validation :
#  Accuracy: 92.8%, Avg loss: 0.216325
#
# ------------------EPOCH 37:------------------
# Loss: 0.216849
# Validation :
#  Accuracy: 92.8%, Avg loss: 0.215491
#
# ------------------EPOCH 38:------------------
# Loss: 0.216063
# Validation :
#  Accuracy: 92.8%, Avg loss: 0.214579
#
# ------------------EPOCH 39:------------------
# Loss: 0.215415
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.214073
#
# ------------------EPOCH 40:------------------
# Loss: 0.214682
# Validation :
#  Accuracy: 92.8%, Avg loss: 0.213302
#
# ------------------EPOCH 41:------------------
# Loss: 0.214029
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.212665
#
# ------------------EPOCH 42:------------------
# Loss: 0.213365
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.211935
#
# ------------------EPOCH 43:------------------
# Loss: 0.212669
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.211275
#
# ------------------EPOCH 44:------------------
# Loss: 0.212066
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.210788
#
# ------------------EPOCH 45:------------------
# Loss: 0.211436
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.210118
#
# ------------------EPOCH 46:------------------
# Loss: 0.210953
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.209536
#
# ------------------EPOCH 47:------------------
# Loss: 0.210227
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.208921
#
# ------------------EPOCH 48:------------------
# Loss: 0.209756
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.208351
#
# ------------------EPOCH 49:------------------
# Loss: 0.209112
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.207904
#
# ------------------EPOCH 50:------------------
# Loss: 0.208547
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.207258
#
# ------------------EPOCH 51:------------------
# Loss: 0.208004
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.206881
#
# ------------------EPOCH 52:------------------
# Loss: 0.207441
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.206265
#
# ------------------EPOCH 53:------------------
# Loss: 0.206888
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.205938
#
# ------------------EPOCH 54:------------------
# Loss: 0.206508
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.205303
#
# ------------------EPOCH 55:------------------
# Loss: 0.205946
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.204935
#
# ------------------EPOCH 56:------------------
# Loss: 0.205401
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.204413
#
# ------------------EPOCH 57:------------------
# Loss: 0.204964
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.204244
#
# ------------------EPOCH 58:------------------
# Loss: 0.204546
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.203487
#
# ------------------EPOCH 59:------------------
# Loss: 0.204063
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.203264
#
# ------------------EPOCH 60:------------------
# Loss: 0.203687
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.202701
#
# ------------------EPOCH 61:------------------
# Loss: 0.203213
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.202351
#
# ------------------EPOCH 62:------------------
# Loss: 0.202805
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.202060
#
# ------------------EPOCH 63:------------------
# Loss: 0.202456
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.201683
#
# ------------------EPOCH 64:------------------
# Loss: 0.202056
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.201184
#
# ------------------EPOCH 65:------------------
# Loss: 0.201704
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.200790
#
# ------------------EPOCH 66:------------------
# Loss: 0.201349
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.200576
#
# ------------------EPOCH 67:------------------
# Loss: 0.200985
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.200089
#
# ------------------EPOCH 68:------------------
# Loss: 0.200652
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.199995
#
# ------------------EPOCH 69:------------------
# Loss: 0.200365
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.199477
#
# ------------------EPOCH 70:------------------
# Loss: 0.199971
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.199119
#
# ------------------EPOCH 71:------------------
# Loss: 0.199612
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.198904
#
# ------------------EPOCH 72:------------------
# Loss: 0.199286
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.198668
#
# ------------------EPOCH 73:------------------
# Loss: 0.198985
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.198270
#
# ------------------EPOCH 74:------------------
# Loss: 0.198706
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.197989
#
# ------------------EPOCH 75:------------------
# Loss: 0.198471
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.197752
#
# ------------------EPOCH 76:------------------
# Loss: 0.198146
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.197621
#
# ------------------EPOCH 77:------------------
# Loss: 0.197830
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.197177
#
# ------------------EPOCH 78:------------------
# Loss: 0.197539
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196971
#
# ------------------EPOCH 79:------------------
# Loss: 0.197290
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196712
#
# ------------------EPOCH 80:------------------
# Loss: 0.197063
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196366
#
# ------------------EPOCH 81:------------------
# Loss: 0.196762
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196111
#
# ------------------EPOCH 82:------------------
# Loss: 0.196578
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195878
#
# ------------------EPOCH 83:------------------
# Loss: 0.196346
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195670
#
# ------------------EPOCH 84:------------------
# Loss: 0.196003
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195469
#
# ------------------EPOCH 85:------------------
# Loss: 0.195850
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195284
#
# ------------------EPOCH 86:------------------
# Loss: 0.195608
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195104
#
# ------------------EPOCH 87:------------------
# Loss: 0.195333
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195169
#
# ------------------EPOCH 88:------------------
# Loss: 0.195192
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.194569
#
# ------------------EPOCH 89:------------------
# Loss: 0.194974
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.194693
#
# ------------------EPOCH 90:------------------
# Loss: 0.194791
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.194439
#
# ------------------EPOCH 91:------------------
# Loss: 0.194514
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.194056
#
# ------------------EPOCH 92:------------------
# Loss: 0.194421
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.194034
#
# ------------------EPOCH 93:------------------
# Loss: 0.194121
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.193930
#
# ------------------EPOCH 94:------------------
# Loss: 0.193977
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.193550
#
# ------------------EPOCH 95:------------------
# Loss: 0.193842
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.193569
#
# ------------------EPOCH 96:------------------
# Loss: 0.193666
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.193336
#
# ------------------EPOCH 97:------------------
# Loss: 0.193537
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.193093
#
# ------------------EPOCH 98:------------------
# Loss: 0.193385
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.193002
#
# ------------------EPOCH 99:------------------
# Loss: 0.193185
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192839
#
# ------------------EPOCH 100:------------------
# Loss: 0.193052
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192676

# %% [markdown]
# ### Evaluate

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')

print(len(train_losses), len(val_losses))

plt.title('Model Loss Training History')
plt.xlabel('Epochs/Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 100 100
