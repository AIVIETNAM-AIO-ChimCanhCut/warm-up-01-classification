# %% [markdown]
# ## Data Preprocessing — Customer Churn Classification
#
# Pipeline: Drop ID → Handle Missing → Encode Categoricals → Feature Engineering → Split → Scale

# %% [markdown]
# ### Imports & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, StandardScaler

train = pd.read_csv("/content/data/churn_train.csv")
test = pd.read_csv("/content/data/churn_test.csv")

train_df = pd.concat([train, test], axis = 0)
print(f"Train shape: {train_df.shape}")
# Out:
# Train shape: (505207, 12)

# %% [markdown]
# ### 1. Drop cột không cần thiết
#
# - `CustomerID` là cột định danh, không mang thông tin dự đoán
# - Nếu giữ lại, model sẽ "memorize" ID → overfitting

# %%
drop_cols = ["CustomerID"]

train_df = train_df.drop(columns=drop_cols)

print(f"Train columns: {train_df.columns.tolist()}")
print(f"Train shape sau khi drop: {train_df.shape}")
# Out:
# Train columns: ['Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'Churn']
# Train shape sau khi drop: (505207, 11)

# %% [markdown]
# ### 2. Xử lý Missing Values
#
# - Train có đúng **1 dòng** (index 199295) tất cả cột đều null
# - Test **không có** missing values

# %%
# Kiểm tra missing trước khi xử lý
print(f"Train missing rows: {train_df.isnull().any(axis=1).sum()}")

# Drop dòng missing
train_df = train_df.dropna()

# Reset index
train_df = train_df.reset_index(drop=True)

print("--- Sau Khi Xử Lý ---")
print(f"Train shape: {train_df.shape}")
print(f"Train missing: {train_df.isnull().sum().sum()}")
# Out:
# Train missing rows: 1
# --- Sau Khi Xử Lý ---
# Train shape: (505206, 11)
# Train missing: 0

# %% [markdown]
# ### 3. Encode Categorical Features
#
# | Cột | Giá trị | Phương pháp | Lý do |
# |-----|---------|-------------|-------|
# | `Gender` | Female, Male | LabelEncoder | Binary → 0/1 |
# | `Subscription Type` | Basic, Standard, Premium | OrdinalEncoder | Có thứ bậc tự nhiên |
# | `Contract Length` | Monthly, Quarterly, Annual | OrdinalEncoder | Có thứ bậc tự nhiên |

# %%
# Kiểm tra các giá trị unique trước khi encode
print("Gender:", train_df["Gender"].unique())
print("Subscription Type:", train_df["Subscription Type"].unique())
print("Contract Length:", train_df["Contract Length"].unique())
# Out:
# Gender: ['Female' 'Male']
# Subscription Type: ['Standard' 'Basic' 'Premium']
# Contract Length: ['Annual' 'Monthly' 'Quarterly']

# %%
# --- Gender: Binary → LabelEncoder ---
le_gender = LabelEncoder()
train_df["Gender"] = le_gender.fit_transform(train_df["Gender"])

print(f"Gender mapping: {dict(zip(le_gender.classes_, le_gender.transform(le_gender.classes_)))}")
# Out:
# Gender mapping: {'Female': np.int64(0), 'Male': np.int64(1)}

# %%
# --- Subscription Type: Ordinal (Basic = 0 < Standard = 1 < Premium = 2) ---
sub_categories = [["Basic", "Standard", "Premium"]]
oe_sub = OrdinalEncoder(categories=sub_categories)

train_df["Subscription Type"] = oe_sub.fit_transform(train_df[["Subscription Type"]])

print(f"Subscription Type mapping: Basic=0, Standard=1, Premium=2")
print(f"Unique values: {sorted(train_df['Subscription Type'].unique())}")
# Out:
# Subscription Type mapping: Basic=0, Standard=1, Premium=2
# Unique values: [np.float64(0.0), np.float64(1.0), np.float64(2.0)]

# %%
# --- Contract Length: Ordinal (Monthly=0 < Quarterly=1 < Annual=2) ---
contract_categories = [["Monthly", "Quarterly", "Annual"]]
oe_contract = OrdinalEncoder(categories=contract_categories)

train_df["Contract Length"] = oe_contract.fit_transform(train_df[["Contract Length"]])

print(f"Contract Length mapping: Monthly=0, Quarterly=1, Annual=2")
print(f"Unique values: {sorted(train_df['Contract Length'].unique())}")
# Out:
# Contract Length mapping: Monthly=0, Quarterly=1, Annual=2
# Unique values: [np.float64(0.0), np.float64(1.0), np.float64(2.0)]

# %%
# Kiểm tra toàn bộ dtypes sau khi encode
print("=== Data types sau encoding ===")
print(train_df.dtypes)
print(f"\nTrain shape: {train_df.shape}")
train_df.head()
# Out:
# === Data types sau encoding ===
# Age                  float64
# Gender                 int64
# Tenure               float64
# Usage Frequency      float64
# Support Calls        float64
# Payment Delay        float64
# Subscription Type    float64
# Contract Length      float64
# Total Spend          float64
# Last Interaction     float64
# Churn                float64
# dtype: object
#
# Train shape: (505206, 11)
#     Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0  30.0       0    39.0             14.0            5.0           18.0
# 1  65.0       0    49.0              1.0           10.0            8.0
# 2  55.0       0    14.0              4.0            6.0           18.0
# 3  58.0       1    38.0             21.0            7.0            7.0
# 4  23.0       1    32.0             20.0            5.0            8.0
#
#    Subscription Type  Contract Length  Total Spend  Last Interaction  Churn
# 0                1.0              2.0        932.0              17.0    1.0
# 1                0.0              0.0        557.0               6.0    1.0
# 2                0.0              1.0        185.0               3.0    1.0
# 3                1.0              0.0        396.0              29.0    1.0
# 4                0.0              0.0        617.0              20.0    1.0

# %% [markdown]
# ### 4. Feature Engineering
#
# Tạo các feature mới dựa trên domain knowledge:
#
# | Feature | Công thức | Ý nghĩa |
# |---------|----------|----------|
# | `Spend_per_Tenure` | Total Spend / Tenure | Chi tiêu TB mỗi tháng |
# | `Usage_per_Tenure` | Usage Frequency / Tenure | Mức sử dụng theo thời gian |
# | `Support_per_Tenure` | Support Calls / Tenure | Tần suất gọi support |
# | `Delay_x_Support` | Payment Delay × Support Calls | Risk interaction feature |

# %%
def add_features(df):
    """Tạo các features mới cho DataFrame."""
    df = df.copy()

    # Chi tiêu trung bình mỗi nhiệm kỳ
    df["Spend_per_Tenure"] = df["Total Spend"] / df["Tenure"]

    # Mức sử dụng dịch vụ theo thời gian
    df["Usage_per_Tenure"] = df["Usage Frequency"] / df["Tenure"]

    # Tần suất liên hệ hỗ trợ theo thời gian
    df["Support_per_Tenure"] = df["Support Calls"] / df["Tenure"]

    # Interaction: khách hàng vừa trễ hạn vừa gọi support nhiều => risk cao
    df["Delay_x_Support"] = df["Payment Delay"] * df["Support Calls"]

    return df

train_df = add_features(train_df)

print(f"Train shape sau feature engineering: {train_df.shape}")
print(f"\nCác cột mới: {train_df.columns.tolist()[-4:]}")
train_df.head()
# Out:
# Train shape sau feature engineering: (505206, 15)
#
# Các cột mới: ['Spend_per_Tenure', 'Usage_per_Tenure', 'Support_per_Tenure', 'Delay_x_Support']
#     Age  Gender  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0  30.0       0    39.0             14.0            5.0           18.0
# 1  65.0       0    49.0              1.0           10.0            8.0
# 2  55.0       0    14.0              4.0            6.0           18.0
# 3  58.0       1    38.0             21.0            7.0            7.0
# 4  23.0       1    32.0             20.0            5.0            8.0
#
#    Subscription Type  Contract Length  Total Spend  Last Interaction  Churn  \
# 0                1.0              2.0        932.0              17.0    1.0
# 1                0.0              0.0        557.0               6.0    1.0
# 2                0.0              1.0        185.0               3.0    1.0
# 3                1.0              0.0        396.0              29.0    1.0
# 4                0.0              0.0        617.0              20.0    1.0
#
#    Spend_per_Tenure  Usage_per_Tenure  Support_per_Tenure  Delay_x_Support
# 0         23.897436          0.358974            0.128205             90.0
# 1         11.367347          0.020408            0.204082             80.0
# 2         13.214286          0.285714            0.428571            108.0
# 3         10.421053          0.552632            0.184211             49.0
# 4         19.281250          0.625000            0.156250             40.0

# %%
# Kiểm tra có inf hay NaN sau feature engineering không
print("--- Kiểm tra giá trị bất thường ---")
print(f"Inf values in train: {np.isinf(train_df.select_dtypes(include=[np.number])).sum().sum()}")
print(f"NaN values in train: {train_df.isnull().sum().sum()}")
# Out:
# --- Kiểm tra giá trị bất thường ---
# Inf values in train: 0
# NaN values in train: 0

# %% [markdown]
# ### 5. Tách dữ liệu: Train / Validation / Test
#
# - **Train** (80%): huấn luyện model
# - **Validation** (20%): đánh giá & tune hyperparameters
# - **Test**: đánh giá cuối cùng (chỉ dùng 1 lần)
# - Dùng `stratify` để giữ tỷ lệ class balance

# %%
# Tách features và target
TARGET = "Churn"

X_train_full = train_df.drop(columns=[TARGET])
y_train_full = train_df[TARGET]

# Lưu tên features để dùng cho feature importance
feature_names = X_train_full.columns.tolist()
print(f"Feature names ({len(feature_names)}): {feature_names}")
# Out:
# Feature names (14): ['Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'Spend_per_Tenure', 'Usage_per_Tenure', 'Support_per_Tenure', 'Delay_x_Support']

# %%
# Split: 80% train, 20% validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    random_state=42,
    # giữ tỉ lệ Churn/Not Churn
    stratify=y_train_full
)

print(f"X_train: {X_train.shape} | y_train Churn ratio: {y_train.mean():.4f}")
print(f"X_val:  {X_val.shape}  | y_val Churn ratio:  {y_val.mean():.4f}")
# Out:
# X_train: (404164, 14) | y_train Churn ratio: 0.5552
# X_val:  (101042, 14)  | y_val Churn ratio:  0.5552

# %% [markdown]
# ### 6. Feature Scaling
#
# - Dùng `StandardScaler`: chuẩn hóa về mean=0, std=1

# %%
scaler = StandardScaler()

# chỉ fit trên tập train để tránh data leakage
X_train_scaled = scaler.fit_transform(X_train)

X_val_scaled = scaler.transform(X_val)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=feature_names)
X_val_scaled = pd.DataFrame(X_val_scaled, columns=feature_names)

y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)

print("=== Thống kê X_train sau scaling ===")
print(X_train_scaled.describe().round(4))
# Out:
# === Thống kê X_train sau scaling ===
#                Age       Gender       Tenure  Usage Frequency  Support Calls  \
# count  404164.0000  404164.0000  404164.0000      404164.0000    404164.0000
# mean        0.0000       0.0000       0.0000          -0.0000         0.0000
# std         1.0000       1.0000       1.0000           1.0000         1.0000
# min        -1.7126      -1.1167      -1.7616          -1.7085        -1.2225
# 25%        -0.8445      -1.1167      -0.8914          -0.8965        -0.9034
# 50%         0.0235       0.8955       0.0369           0.0314        -0.2652
# 75%         0.7338       0.8955       0.8491           0.8433         0.6921
# max         1.9964       0.8955       1.6613           1.6552         1.9685
#
#        Payment Delay  Subscription Type  Contract Length  Total Spend  \
# count    404164.0000        404164.0000      404164.0000  404164.0000
# mean          0.0000            -0.0000           0.0000      -0.0000
# std           1.0000             1.0000           1.0000       1.0000
# min          -1.5974            -1.2415          -1.5488      -2.1200
# 25%          -0.8874            -1.2415          -0.2329      -0.7094
# 50%          -0.0591            -0.0129          -0.2329       0.1180
# 75%           0.7693             1.2156           1.0830       0.8315
# max           1.9526             1.2156           1.0830       1.5492
#
#        Last Interaction  Spend_per_Tenure  Usage_per_Tenure  \
# count       404164.0000       404164.0000       404164.0000
# mean             0.0000            0.0000            0.0000
# std              1.0000            1.0000            1.0000
# min             -1.5814           -0.4717           -0.4543
# 25%             -0.8843           -0.3519           -0.3555
# 50%             -0.0710           -0.2764           -0.2588
# 75%              0.8585           -0.0856           -0.0566
# max              1.7881           10.4003           11.6721
#
#        Support_per_Tenure  Delay_x_Support
# count         404164.0000      404164.0000
# mean              -0.0000          -0.0000
# std                1.0000           1.0000
# min               -0.3866          -0.8463
# 25%               -0.3375          -0.7412
# 50%               -0.2398          -0.4111
# 75%               -0.0625           0.4144
# max               13.1184           3.6561

# %% [markdown]
# ### 8. Tổng Kết

# %%
print("=" * 60)
print("PREPROCESSING SUMMARY")
print("=" * 60)
print(f"\n Dataset sizes:")
print(f"   Train:      {X_train_scaled.shape}")
print(f"   Validation:       {X_val_scaled.shape}")
print(f"\n Features ({len(feature_names)}):")
for i, feat in enumerate(feature_names, 1):
    print(f"   {i:2d}. {feat}")
print(f"\n Target: Churn (binary)")
print(f"   Train Churn ratio:  {y_train.mean():.4f}")
print(f"   Validation Churn ratio:   {y_val.mean():.4f}")
print(f"\n Missing values: 0")
# Out:
# ============================================================
# PREPROCESSING SUMMARY
# ============================================================
#
#  Dataset sizes:
#    Train:      (404164, 14)
#    Validation:       (101042, 14)
#
#  Features (14):
#     1. Age
#     2. Gender
#     3. Tenure
#     4. Usage Frequency
#     5. Support Calls
#     6. Payment Delay
#     7. Subscription Type
#     8. Contract Length
#     9. Total Spend
#    10. Last Interaction
#    11. Spend_per_Tenure
#    12. Usage_per_Tenure
#    13. Support_per_Tenure
#    14. Delay_x_Support
#
#  Target: Churn (binary)
#    Train Churn ratio:  0.5552
#    Validation Churn ratio:   0.5552
#
#  Missing values: 0

# %% [markdown]
# ---
#
# ### Ghi chú cho bước tiếp theo (Model Training)
#
# Các biến sẵn sàng để sử dụng:
# - `X_train_scaled`, `y_train` → Huấn luyện model
# - `X_val_scaled`, `y_val` → Đánh giá
# - `feature_names` → Tên các features (cho feature importance)
# - `scaler` → Scaler object (cần save để dùng cho inference)

# %% [markdown]
# ## Modeling — Using Deep learning

# %% [markdown]
# ### Import libraries

# %%
# !pip install pytorch-tabnet
# Out:
# Requirement already satisfied: pytorch-tabnet in /usr/local/lib/python3.12/dist-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (2.0.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (1.16.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (2.10.0+cu128)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (4.67.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.3->pytorch-tabnet) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.3->pytorch-tabnet) (3.0.3)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from pytorch_tabnet.tab_model import TabNetClassifier

# %% [markdown]
# ### Define Hyperparameters

# %%
EPOCHS = 100
BATCH_SIZE = 256
LR = 0.0001

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device}")
# Out:
# Using cuda

# %% [markdown]
# ### Define dataset

# %%
X_train_scaled, y_train = X_train_scaled.to_numpy(), y_train.to_numpy()
X_val_scaled, y_val = X_val_scaled.to_numpy(), y_val.to_numpy()

# %%
class ChurnDataset(Dataset):
    def __init__(self, X, y) -> None:
        super().__init__()
        self.X = torch.tensor(X, dtype=torch.float).to(device)
        self.y = torch.tensor(y, dtype=torch.float).to(device)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
train_churn_dataset = ChurnDataset(X_train_scaled, y_train)
val_churn_dataset = ChurnDataset(X_val_scaled, y_val)

train_loader = DataLoader(train_churn_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_churn_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### Define models
#
# Baseline: Input(14) -> Hidden(64) -> Hidden(32) -> Output(1)

# %%
class BaseNeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),

            nn.Linear(64, 32),
            nn.ReLU(),

            nn.Linear(32, output_dim),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.fc(input)

# %%
clf = TabNetClassifier(
    n_d=16, n_a=16,
    n_steps=3,
    gamma=1.5,
    n_independent=2,
    n_shared=2,
    lambda_sparse=1e-3,
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=2e-2, weight_decay=1e-5),
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    scheduler_params={"step_size":10, "gamma":0.9},
    mask_type='entmax'
)
# Out:
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")

# %% [markdown]
# #Train models

# %%
base_nn = BaseNeuralNetwork(14, 1).to(device)
loss_fn = nn.BCELoss()
optimizer = torch.optim.Adam(base_nn.parameters(), lr=LR)

# %%
def train_and_val_loop(train_loader, val_loader, model, loss_fn, optimizer):
    train_losses, val_losses = [], []

    for i in range(EPOCHS):
        model.train()
        running_loss = 0.0

        print(f"------------------EPOCH {i+1}:------------------")
        for batch, (X, y) in enumerate(train_loader):
            y_pred = model(X)
            y_pred = y_pred.squeeze()
            loss = loss_fn(y_pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        print(f"Loss: {avg_loss:>7f}")
        train_losses.append(avg_loss)

        val_loss = val_loop(val_loader, model, loss_fn)
        val_losses.append(val_loss)

    return train_losses, val_losses

def val_loop(data_loader, model, loss_fn):
    num_batches = len(data_loader)
    size = len(data_loader.dataset)
    total_loss, correct = 0, 0

    model.eval()
    with torch.no_grad():
      for X, y in data_loader:
          y_pred = model(X)
          y_pred = y_pred.squeeze()
          loss = loss_fn(y_pred, y)

          total_loss += loss.item()
          predictions = (y_pred >= 0.5).float()
          correct += (predictions == y).float().sum().item()

    total_loss /= num_batches
    correct /= size
    print(f"Validation : \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {total_loss:>8f} \n")
    return total_loss

# %%
train_losses, val_losses = train_and_val_loop(train_loader, val_loader, base_nn, loss_fn, optimizer)
# Out:
# ------------------EPOCH 1:------------------
# Loss: 0.422738
# Validation :
#  Accuracy: 86.5%, Avg loss: 0.344055
#
# ------------------EPOCH 2:------------------
# Loss: 0.322313
# Validation :
#  Accuracy: 89.1%, Avg loss: 0.301150
#
# ------------------EPOCH 3:------------------
# Loss: 0.291788
# Validation :
#  Accuracy: 90.2%, Avg loss: 0.280436
#
# ------------------EPOCH 4:------------------
# Loss: 0.277200
# Validation :
#  Accuracy: 90.7%, Avg loss: 0.269422
#
# ------------------EPOCH 5:------------------
# Loss: 0.268256
# Validation :
#  Accuracy: 91.0%, Avg loss: 0.262048
#
# ------------------EPOCH 6:------------------
# Loss: 0.261991
# Validation :
#  Accuracy: 91.2%, Avg loss: 0.256558
#
# ------------------EPOCH 7:------------------
# Loss: 0.257139
# Validation :
#  Accuracy: 91.4%, Avg loss: 0.252119
#
# ------------------EPOCH 8:------------------
# Loss: 0.252990
# Validation :
#  Accuracy: 91.5%, Avg loss: 0.248551
#
# ------------------EPOCH 9:------------------
# Loss: 0.249354
# Validation :
#  Accuracy: 91.6%, Avg loss: 0.245149
#
# ------------------EPOCH 10:------------------
# Loss: 0.245995
# Validation :
#  Accuracy: 91.8%, Avg loss: 0.242148
#
# ------------------EPOCH 11:------------------
# Loss: 0.243011
# Validation :
#  Accuracy: 91.8%, Avg loss: 0.239326
#
# ------------------EPOCH 12:------------------
# Loss: 0.240237
# Validation :
#  Accuracy: 91.9%, Avg loss: 0.237119
#
# ------------------EPOCH 13:------------------
# Loss: 0.237709
# Validation :
#  Accuracy: 92.0%, Avg loss: 0.234547
#
# ------------------EPOCH 14:------------------
# Loss: 0.235343
# Validation :
#  Accuracy: 92.1%, Avg loss: 0.232479
#
# ------------------EPOCH 15:------------------
# Loss: 0.233228
# Validation :
#  Accuracy: 92.2%, Avg loss: 0.230381
#
# ------------------EPOCH 16:------------------
# Loss: 0.231213
# Validation :
#  Accuracy: 92.3%, Avg loss: 0.228700
#
# ------------------EPOCH 17:------------------
# Loss: 0.229357
# Validation :
#  Accuracy: 92.4%, Avg loss: 0.226895
#
# ------------------EPOCH 18:------------------
# Loss: 0.227568
# Validation :
#  Accuracy: 92.4%, Avg loss: 0.225257
#
# ------------------EPOCH 19:------------------
# Loss: 0.225876
# Validation :
#  Accuracy: 92.5%, Avg loss: 0.223641
#
# ------------------EPOCH 20:------------------
# Loss: 0.224289
# Validation :
#  Accuracy: 92.5%, Avg loss: 0.222278
#
# ------------------EPOCH 21:------------------
# Loss: 0.222758
# Validation :
#  Accuracy: 92.6%, Avg loss: 0.220642
#
# ------------------EPOCH 22:------------------
# Loss: 0.221323
# Validation :
#  Accuracy: 92.6%, Avg loss: 0.219254
#
# ------------------EPOCH 23:------------------
# Loss: 0.219923
# Validation :
#  Accuracy: 92.7%, Avg loss: 0.217860
#
# ------------------EPOCH 24:------------------
# Loss: 0.218600
# Validation :
#  Accuracy: 92.8%, Avg loss: 0.217000
#
# ------------------EPOCH 25:------------------
# Loss: 0.217367
# Validation :
#  Accuracy: 92.7%, Avg loss: 0.215509
#
# ------------------EPOCH 26:------------------
# Loss: 0.216175
# Validation :
#  Accuracy: 92.8%, Avg loss: 0.214369
#
# ------------------EPOCH 27:------------------
# Loss: 0.215044
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.213185
#
# ------------------EPOCH 28:------------------
# Loss: 0.213973
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.212363
#
# ------------------EPOCH 29:------------------
# Loss: 0.212952
# Validation :
#  Accuracy: 92.9%, Avg loss: 0.211320
#
# ------------------EPOCH 30:------------------
# Loss: 0.211930
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.210296
#
# ------------------EPOCH 31:------------------
# Loss: 0.210996
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.209403
#
# ------------------EPOCH 32:------------------
# Loss: 0.210042
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.208662
#
# ------------------EPOCH 33:------------------
# Loss: 0.209142
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.208046
#
# ------------------EPOCH 34:------------------
# Loss: 0.208257
# Validation :
#  Accuracy: 93.0%, Avg loss: 0.207036
#
# ------------------EPOCH 35:------------------
# Loss: 0.207410
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.206317
#
# ------------------EPOCH 36:------------------
# Loss: 0.206658
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.205603
#
# ------------------EPOCH 37:------------------
# Loss: 0.205887
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.204968
#
# ------------------EPOCH 38:------------------
# Loss: 0.205173
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.204208
#
# ------------------EPOCH 39:------------------
# Loss: 0.204504
# Validation :
#  Accuracy: 93.1%, Avg loss: 0.203531
#
# ------------------EPOCH 40:------------------
# Loss: 0.203864
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.202738
#
# ------------------EPOCH 41:------------------
# Loss: 0.203233
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.202164
#
# ------------------EPOCH 42:------------------
# Loss: 0.202589
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.201602
#
# ------------------EPOCH 43:------------------
# Loss: 0.202034
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.201205
#
# ------------------EPOCH 44:------------------
# Loss: 0.201412
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.200516
#
# ------------------EPOCH 45:------------------
# Loss: 0.200906
# Validation :
#  Accuracy: 93.2%, Avg loss: 0.200229
#
# ------------------EPOCH 46:------------------
# Loss: 0.200351
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.199504
#
# ------------------EPOCH 47:------------------
# Loss: 0.199867
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.199098
#
# ------------------EPOCH 48:------------------
# Loss: 0.199362
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.198647
#
# ------------------EPOCH 49:------------------
# Loss: 0.198904
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.198192
#
# ------------------EPOCH 50:------------------
# Loss: 0.198418
# Validation :
#  Accuracy: 93.3%, Avg loss: 0.197858
#
# ------------------EPOCH 51:------------------
# Loss: 0.197976
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.197488
#
# ------------------EPOCH 52:------------------
# Loss: 0.197597
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.197071
#
# ------------------EPOCH 53:------------------
# Loss: 0.197169
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196715
#
# ------------------EPOCH 54:------------------
# Loss: 0.196827
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196255
#
# ------------------EPOCH 55:------------------
# Loss: 0.196454
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.196098
#
# ------------------EPOCH 56:------------------
# Loss: 0.196088
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195681
#
# ------------------EPOCH 57:------------------
# Loss: 0.195748
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195361
#
# ------------------EPOCH 58:------------------
# Loss: 0.195432
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.195407
#
# ------------------EPOCH 59:------------------
# Loss: 0.195151
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.194646
#
# ------------------EPOCH 60:------------------
# Loss: 0.194870
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.194472
#
# ------------------EPOCH 61:------------------
# Loss: 0.194597
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.194306
#
# ------------------EPOCH 62:------------------
# Loss: 0.194288
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.193876
#
# ------------------EPOCH 63:------------------
# Loss: 0.194027
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.193653
#
# ------------------EPOCH 64:------------------
# Loss: 0.193802
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.193406
#
# ------------------EPOCH 65:------------------
# Loss: 0.193520
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.193246
#
# ------------------EPOCH 66:------------------
# Loss: 0.193291
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.192924
#
# ------------------EPOCH 67:------------------
# Loss: 0.193076
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192810
#
# ------------------EPOCH 68:------------------
# Loss: 0.192827
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192663
#
# ------------------EPOCH 69:------------------
# Loss: 0.192636
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192230
#
# ------------------EPOCH 70:------------------
# Loss: 0.192425
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192103
#
# ------------------EPOCH 71:------------------
# Loss: 0.192234
# Validation :
#  Accuracy: 93.4%, Avg loss: 0.192006
#
# ------------------EPOCH 72:------------------
# Loss: 0.192014
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.191821
#
# ------------------EPOCH 73:------------------
# Loss: 0.191840
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.192141
#
# ------------------EPOCH 74:------------------
# Loss: 0.191610
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.191390
#
# ------------------EPOCH 75:------------------
# Loss: 0.191460
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.191340
#
# ------------------EPOCH 76:------------------
# Loss: 0.191274
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.191127
#
# ------------------EPOCH 77:------------------
# Loss: 0.191127
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.191000
#
# ------------------EPOCH 78:------------------
# Loss: 0.190892
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190832
#
# ------------------EPOCH 79:------------------
# Loss: 0.190789
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190585
#
# ------------------EPOCH 80:------------------
# Loss: 0.190615
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190438
#
# ------------------EPOCH 81:------------------
# Loss: 0.190461
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190263
#
# ------------------EPOCH 82:------------------
# Loss: 0.190234
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190249
#
# ------------------EPOCH 83:------------------
# Loss: 0.190124
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190002
#
# ------------------EPOCH 84:------------------
# Loss: 0.190020
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.190038
#
# ------------------EPOCH 85:------------------
# Loss: 0.189833
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189830
#
# ------------------EPOCH 86:------------------
# Loss: 0.189691
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189655
#
# ------------------EPOCH 87:------------------
# Loss: 0.189590
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.189763
#
# ------------------EPOCH 88:------------------
# Loss: 0.189446
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189645
#
# ------------------EPOCH 89:------------------
# Loss: 0.189332
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189483
#
# ------------------EPOCH 90:------------------
# Loss: 0.189213
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189069
#
# ------------------EPOCH 91:------------------
# Loss: 0.189071
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189319
#
# ------------------EPOCH 92:------------------
# Loss: 0.188930
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.189214
#
# ------------------EPOCH 93:------------------
# Loss: 0.188802
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.189113
#
# ------------------EPOCH 94:------------------
# Loss: 0.188725
# Validation :
#  Accuracy: 93.5%, Avg loss: 0.188718
#
# ------------------EPOCH 95:------------------
# Loss: 0.188622
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.188654
#
# ------------------EPOCH 96:------------------
# Loss: 0.188516
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.188491
#
# ------------------EPOCH 97:------------------
# Loss: 0.188449
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.188365
#
# ------------------EPOCH 98:------------------
# Loss: 0.188307
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.188239
#
# ------------------EPOCH 99:------------------
# Loss: 0.188201
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.188338
#
# ------------------EPOCH 100:------------------
# Loss: 0.188086
# Validation :
#  Accuracy: 93.6%, Avg loss: 0.188333

# %%
clf.fit(
    X_train=X_train_scaled, y_train=y_train,
    eval_set=[(X_train_scaled, y_train), (X_val_scaled, y_val)],
    eval_name=['train', 'val'],
    eval_metric=['logloss', 'auc', 'accuracy'],
    max_epochs=EPOCHS,
    patience=15,
    batch_size=BATCH_SIZE,
    drop_last=False
)
# Out:
# epoch 0  | loss: 0.26179 | train_logloss: 0.25978 | train_auc: 0.94179 | train_accuracy: 0.90658 | val_logloss: 0.25895 | val_auc: 0.94182 | val_accuracy: 0.90686 |  0:01:04s
# epoch 1  | loss: 0.23812 | train_logloss: 0.23758 | train_auc: 0.94545 | train_accuracy: 0.92171 | val_logloss: 0.23546 | val_auc: 0.946   | val_accuracy: 0.9224  |  0:02:09s
# epoch 2  | loss: 0.23565 | train_logloss: 0.22057 | train_auc: 0.94843 | train_accuracy: 0.92765 | val_logloss: 0.21918 | val_auc: 0.94869 | val_accuracy: 0.92831 |  0:03:14s
# epoch 3  | loss: 0.23243 | train_logloss: 0.22764 | train_auc: 0.94697 | train_accuracy: 0.92516 | val_logloss: 0.22633 | val_auc: 0.94707 | val_accuracy: 0.92604 |  0:04:18s
# epoch 4  | loss: 0.2323  | train_logloss: 0.21995 | train_auc: 0.94793 | train_accuracy: 0.92574 | val_logloss: 0.21828 | val_auc: 0.9483  | val_accuracy: 0.92658 |  0:05:22s
# epoch 5  | loss: 0.23156 | train_logloss: 0.22153 | train_auc: 0.9481  | train_accuracy: 0.92612 | val_logloss: 0.2203  | val_auc: 0.94808 | val_accuracy: 0.92701 |  0:06:26s
# epoch 6  | loss: 0.22961 | train_logloss: 0.22367 | train_auc: 0.94849 | train_accuracy: 0.92493 | val_logloss: 0.22147 | val_auc: 0.9488  | val_accuracy: 0.9261  |  0:07:31s
# epoch 7  | loss: 0.22852 | train_logloss: 0.21837 | train_auc: 0.94824 | train_accuracy: 0.9271  | val_logloss: 0.21677 | val_auc: 0.94836 | val_accuracy: 0.92784 |  0:08:35s
# epoch 8  | loss: 0.22985 | train_logloss: 0.21989 | train_auc: 0.94795 | train_accuracy: 0.92681 | val_logloss: 0.21786 | val_auc: 0.94876 | val_accuracy: 0.92766 |  0:09:39s
# epoch 9  | loss: 0.22908 | train_logloss: 0.22026 | train_auc: 0.94807 | train_accuracy: 0.926   | val_logloss: 0.21788 | val_auc: 0.94886 | val_accuracy: 0.92673 |  0:10:44s
# epoch 10 | loss: 0.2289  | train_logloss: 0.22554 | train_auc: 0.94836 | train_accuracy: 0.92529 | val_logloss: 0.22387 | val_auc: 0.94862 | val_accuracy: 0.92618 |  0:11:48s
# epoch 11 | loss: 0.22931 | train_logloss: 0.2199  | train_auc: 0.94842 | train_accuracy: 0.92693 | val_logloss: 0.21863 | val_auc: 0.94831 | val_accuracy: 0.92814 |  0:12:53s
# epoch 12 | loss: 0.22961 | train_logloss: 0.22311 | train_auc: 0.94751 | train_accuracy: 0.92539 | val_logloss: 0.22115 | val_auc: 0.94825 | val_accuracy: 0.92605 |  0:13:57s
# epoch 13 | loss: 0.22804 | train_logloss: 0.21716 | train_auc: 0.94875 | train_accuracy: 0.92706 | val_logloss: 0.21536 | val_auc: 0.94871 | val_accuracy: 0.92778 |  0:15:01s
# epoch 14 | loss: 0.22762 | train_logloss: 0.21579 | train_auc: 0.9494  | train_accuracy: 0.92786 | val_logloss: 0.21442 | val_auc: 0.94931 | val_accuracy: 0.92865 |  0:16:05s
# epoch 15 | loss: 0.22851 | train_logloss: 0.21823 | train_auc: 0.94814 | train_accuracy: 0.92762 | val_logloss: 0.21639 | val_auc: 0.94848 | val_accuracy: 0.92807 |  0:17:08s
# epoch 16 | loss: 0.22744 | train_logloss: 0.22046 | train_auc: 0.94831 | train_accuracy: 0.92691 | val_logloss: 0.21923 | val_auc: 0.94853 | val_accuracy: 0.92753 |  0:18:13s
# epoch 17 | loss: 0.22814 | train_logloss: 0.22739 | train_auc: 0.94818 | train_accuracy: 0.92263 | val_logloss: 0.22546 | val_auc: 0.94893 | val_accuracy: 0.9239  |  0:19:18s
# epoch 18 | loss: 0.22836 | train_logloss: 0.24227 | train_auc: 0.94614 | train_accuracy: 0.91787 | val_logloss: 0.24166 | val_auc: 0.94635 | val_accuracy: 0.91783 |  0:20:22s
# epoch 19 | loss: 0.22911 | train_logloss: 0.22786 | train_auc: 0.94746 | train_accuracy: 0.92657 | val_logloss: 0.22622 | val_auc: 0.94791 | val_accuracy: 0.92723 |  0:21:26s
# epoch 20 | loss: 0.22803 | train_logloss: 0.21714 | train_auc: 0.94865 | train_accuracy: 0.92704 | val_logloss: 0.21518 | val_auc: 0.94883 | val_accuracy: 0.92794 |  0:22:30s
# epoch 21 | loss: 0.22906 | train_logloss: 0.22144 | train_auc: 0.94735 | train_accuracy: 0.92525 | val_logloss: 0.22009 | val_auc: 0.94808 | val_accuracy: 0.92597 |  0:23:33s
# epoch 22 | loss: 0.22757 | train_logloss: 0.21593 | train_auc: 0.94909 | train_accuracy: 0.92836 | val_logloss: 0.21425 | val_auc: 0.94911 | val_accuracy: 0.92897 |  0:24:38s
# epoch 23 | loss: 0.22809 | train_logloss: 0.21861 | train_auc: 0.94856 | train_accuracy: 0.92681 | val_logloss: 0.21686 | val_auc: 0.94876 | val_accuracy: 0.92765 |  0:25:42s
# epoch 24 | loss: 0.22835 | train_logloss: 0.21942 | train_auc: 0.94893 | train_accuracy: 0.92634 | val_logloss: 0.21755 | val_auc: 0.94949 | val_accuracy: 0.92709 |  0:26:46s
# epoch 25 | loss: 0.22856 | train_logloss: 0.22066 | train_auc: 0.94825 | train_accuracy: 0.92555 | val_logloss: 0.21921 | val_auc: 0.94842 | val_accuracy: 0.92658 |  0:27:51s
# epoch 26 | loss: 0.22706 | train_logloss: 0.21547 | train_auc: 0.94853 | train_accuracy: 0.92764 | val_logloss: 0.21367 | val_auc: 0.94885 | val_accuracy: 0.92848 |  0:28:56s
# epoch 27 | loss: 0.22802 | train_logloss: 0.22921 | train_auc: 0.94761 | train_accuracy: 0.92683 | val_logloss: 0.22755 | val_auc: 0.94762 | val_accuracy: 0.92776 |  0:30:00s
# epoch 28 | loss: 0.22743 | train_logloss: 0.22149 | train_auc: 0.94715 | train_accuracy: 0.92739 | val_logloss: 0.21982 | val_auc: 0.94791 | val_accuracy: 0.92797 |  0:31:04s
# epoch 29 | loss: 0.2278  | train_logloss: 0.22445 | train_auc: 0.94775 | train_accuracy: 0.9244  | val_logloss: 0.22326 | val_auc: 0.94796 | val_accuracy: 0.92513 |  0:32:08s
# epoch 30 | loss: 0.22676 | train_logloss: 0.21578 | train_auc: 0.94891 | train_accuracy: 0.92709 | val_logloss: 0.21384 | val_auc: 0.94942 | val_accuracy: 0.92806 |  0:33:13s
# epoch 31 | loss: 0.22705 | train_logloss: 0.21866 | train_auc: 0.94868 | train_accuracy: 0.92636 | val_logloss: 0.21778 | val_auc: 0.94895 | val_accuracy: 0.92682 |  0:34:16s
# epoch 32 | loss: 0.227   | train_logloss: 0.21776 | train_auc: 0.94823 | train_accuracy: 0.92689 | val_logloss: 0.21639 | val_auc: 0.94817 | val_accuracy: 0.92726 |  0:35:20s
# epoch 33 | loss: 0.22703 | train_logloss: 0.21576 | train_auc: 0.94909 | train_accuracy: 0.92825 | val_logloss: 0.21452 | val_auc: 0.94886 | val_accuracy: 0.92922 |  0:36:24s
# epoch 34 | loss: 0.22657 | train_logloss: 0.21433 | train_auc: 0.94929 | train_accuracy: 0.92796 | val_logloss: 0.21263 | val_auc: 0.94958 | val_accuracy: 0.9286  |  0:37:31s
# epoch 35 | loss: 0.22622 | train_logloss: 0.21841 | train_auc: 0.94895 | train_accuracy: 0.92679 | val_logloss: 0.21725 | val_auc: 0.94873 | val_accuracy: 0.92763 |  0:38:35s
# epoch 36 | loss: 0.22586 | train_logloss: 0.21928 | train_auc: 0.94865 | train_accuracy: 0.92631 | val_logloss: 0.21789 | val_auc: 0.94943 | val_accuracy: 0.92724 |  0:39:37s
# epoch 37 | loss: 0.22655 | train_logloss: 0.21563 | train_auc: 0.94937 | train_accuracy: 0.92727 | val_logloss: 0.21428 | val_auc: 0.94937 | val_accuracy: 0.92789 |  0:40:41s
# epoch 38 | loss: 0.22638 | train_logloss: 0.2197  | train_auc: 0.94876 | train_accuracy: 0.92686 | val_logloss: 0.2178  | val_auc: 0.94923 | val_accuracy: 0.92791 |  0:41:44s
# epoch 39 | loss: 0.22674 | train_logloss: 0.22535 | train_auc: 0.94669 | train_accuracy: 0.92619 | val_logloss: 0.22413 | val_auc: 0.94695 | val_accuracy: 0.92659 |  0:42:49s
# epoch 40 | loss: 0.22624 | train_logloss: 0.21454 | train_auc: 0.94888 | train_accuracy: 0.92799 | val_logloss: 0.21253 | val_auc: 0.94958 | val_accuracy: 0.9288  |  0:43:53s
# epoch 41 | loss: 0.22512 | train_logloss: 0.21673 | train_auc: 0.94934 | train_accuracy: 0.92626 | val_logloss: 0.21487 | val_auc: 0.94961 | val_accuracy: 0.92716 |  0:44:57s
# epoch 42 | loss: 0.22467 | train_logloss: 0.21809 | train_auc: 0.94855 | train_accuracy: 0.92696 | val_logloss: 0.21668 | val_auc: 0.9485  | val_accuracy: 0.92767 |  0:46:02s
# epoch 43 | loss: 0.22528 | train_logloss: 0.21433 | train_auc: 0.94908 | train_accuracy: 0.92774 | val_logloss: 0.21241 | val_auc: 0.94889 | val_accuracy: 0.92857 |  0:47:06s
# epoch 44 | loss: 0.22447 | train_logloss: 0.21524 | train_auc: 0.94893 | train_accuracy: 0.92732 | val_logloss: 0.21365 | val_auc: 0.94887 | val_accuracy: 0.92811 |  0:48:10s
# epoch 45 | loss: 0.22456 | train_logloss: 0.21288 | train_auc: 0.94933 | train_accuracy: 0.92789 | val_logloss: 0.21158 | val_auc: 0.94941 | val_accuracy: 0.92852 |  0:49:13s
# epoch 46 | loss: 0.2259  | train_logloss: 0.2144  | train_auc: 0.94861 | train_accuracy: 0.92889 | val_logloss: 0.21236 | val_auc: 0.94908 | val_accuracy: 0.92965 |  0:50:16s
# epoch 47 | loss: 0.22456 | train_logloss: 0.21274 | train_auc: 0.94961 | train_accuracy: 0.92807 | val_logloss: 0.21103 | val_auc: 0.94966 | val_accuracy: 0.92881 |  0:51:20s
# epoch 48 | loss: 0.22476 | train_logloss: 0.2107  | train_auc: 0.9495  | train_accuracy: 0.92903 | val_logloss: 0.20909 | val_auc: 0.95007 | val_accuracy: 0.92975 |  0:52:24s
# epoch 49 | loss: 0.2256  | train_logloss: 0.23003 | train_auc: 0.94687 | train_accuracy: 0.92259 | val_logloss: 0.22893 | val_auc: 0.94735 | val_accuracy: 0.92329 |  0:53:28s
# epoch 50 | loss: 0.22401 | train_logloss: 0.21322 | train_auc: 0.94919 | train_accuracy: 0.92783 | val_logloss: 0.21194 | val_auc: 0.94917 | val_accuracy: 0.92859 |  0:54:31s
# epoch 51 | loss: 0.22436 | train_logloss: 0.21617 | train_auc: 0.94834 | train_accuracy: 0.92738 | val_logloss: 0.21402 | val_auc: 0.94884 | val_accuracy: 0.92791 |  0:55:34s
# epoch 52 | loss: 0.22357 | train_logloss: 0.21213 | train_auc: 0.94937 | train_accuracy: 0.92896 | val_logloss: 0.21092 | val_auc: 0.94928 | val_accuracy: 0.92954 |  0:56:36s
# epoch 53 | loss: 0.22353 | train_logloss: 0.21343 | train_auc: 0.94874 | train_accuracy: 0.92829 | val_logloss: 0.21145 | val_auc: 0.94942 | val_accuracy: 0.92913 |  0:57:40s
# epoch 54 | loss: 0.22356 | train_logloss: 0.21344 | train_auc: 0.94923 | train_accuracy: 0.92775 | val_logloss: 0.21177 | val_auc: 0.94952 | val_accuracy: 0.92855 |  0:58:44s
# epoch 55 | loss: 0.22295 | train_logloss: 0.21461 | train_auc: 0.94871 | train_accuracy: 0.92811 | val_logloss: 0.21289 | val_auc: 0.94892 | val_accuracy: 0.92867 |  0:59:47s
# epoch 56 | loss: 0.22367 | train_logloss: 0.21544 | train_auc: 0.94878 | train_accuracy: 0.92611 | val_logloss: 0.21342 | val_auc: 0.94914 | val_accuracy: 0.9272  |  1:00:51s
# epoch 57 | loss: 0.2238  | train_logloss: 0.21471 | train_auc: 0.94883 | train_accuracy: 0.92758 | val_logloss: 0.21335 | val_auc: 0.94864 | val_accuracy: 0.92843 |  1:01:55s
# epoch 58 | loss: 0.224   | train_logloss: 0.21442 | train_auc: 0.94854 | train_accuracy: 0.92826 | val_logloss: 0.21286 | val_auc: 0.94861 | val_accuracy: 0.92894 |  1:02:59s
# epoch 59 | loss: 0.22398 | train_logloss: 0.21343 | train_auc: 0.94925 | train_accuracy: 0.92766 | val_logloss: 0.21191 | val_auc: 0.94974 | val_accuracy: 0.92843 |  1:04:03s
# epoch 60 | loss: 0.22295 | train_logloss: 0.21249 | train_auc: 0.94911 | train_accuracy: 0.92819 | val_logloss: 0.21081 | val_auc: 0.94959 | val_accuracy: 0.92915 |  1:05:06s
# epoch 61 | loss: 0.22309 | train_logloss: 0.21519 | train_auc: 0.9485  | train_accuracy: 0.92854 | val_logloss: 0.21404 | val_auc: 0.94869 | val_accuracy: 0.92952 |  1:06:10s
# epoch 62 | loss: 0.22311 | train_logloss: 0.21232 | train_auc: 0.94875 | train_accuracy: 0.92855 | val_logloss: 0.21021 | val_auc: 0.94916 | val_accuracy: 0.9295  |  1:07:14s
# epoch 63 | loss: 0.22411 | train_logloss: 0.21431 | train_auc: 0.94908 | train_accuracy: 0.92692 | val_logloss: 0.2132  | val_auc: 0.94936 | val_accuracy: 0.9275  |  1:08:19s
#
# Early stopping occurred at epoch 63 with best_epoch = 48 and best_val_accuracy = 0.92975
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# ### Evaluate

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')

print(len(train_losses), len(val_losses))

plt.title('Model Loss Training History')
plt.xlabel('Epochs/Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 100 100

# %%
plt.plot(clf.history['loss'], label='Train Loss', color='#1f77b4')
plt.plot(clf.history['val_logloss'], label='Val Loss', color='#ff7f0e')

plt.title('TabNet Model Loss Training History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
